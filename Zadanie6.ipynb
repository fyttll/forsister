# %%
import pandas as pd 
 
file_path = r"C:\Users\User\Desktop\test\forsister\web_clients_correct.csv"
web_clients_df = pd.read_csv(file_path) 
 
web_clients_df.head(), web_clients_df.info()

web_clients_df['age_category'] = web_clients_df['age'].apply( 
    lambda x: 'Старше 25' if x > 25 else 'Младше или равен 25' 
) 

web_clients_df[['name', 'age', 'age_category']].head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         915 non-null    object
#  1   device_type  867 non-null    object
#  2   browser      867 non-null    object
#  3   sex          867 non-null    object
#  4   age          867 non-null    float64
#  5   bill         867 non-null    float64
#  6   region       867 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 50.2+ KB
#                                                  name   age  \
# 0                       Allen  Miss. Elisabeth Walton  29.0
# 1                      Allison  Master. Hudson Trevor  48.0
# 2                        Allison  Miss. Helen Loraine  48.0
# 3                Allison  Mr. Hudson Joshua Creighton  30.0
# 4     Allison  Mrs. Hudson J C (Bessie Waldo Daniels)  25.0
# 5                                 Anderson  Mr. Harry  48.0
# ...

# %%
filtered_df = web_clients_df[(web_clients_df['sex'] == 'male') & (web_clients_df['age'] > 30)] 
 
filtered_df.head(15)
# Out:
#                                     name device_type            browser   sex  \
# 1         Allison  Master. Hudson Trevor      tablet              Opera  male
# 5                    Anderson  Mr. Harry      mobile            Firefox  male
# 7                 Andrews  Mr. Thomas Jr      tablet  Internet Explorer  male
# 9                Artagaveytia  Mr. Ramon      mobile            Firefox  male
# 10                Astor  Col. John Jacob     desktop             Chrome  male
# 14  Barkworth  Mr. Algernon Henry Wilson      laptop             Chrome  male
# 15                   Baumann  Mr. John D      tablet              Opera  male
# 19                  Beattie  Mr. Thomson      mobile             Chrome  male
# 20         Beckwith  Mr. Richard Leonard     desktop            Firefox  male
# 30          Blackwell  Mr. Stephen Weart      mobile             Chrome  male
# 31                      Blank  Mr. Henry      tablet  Internet Explorer  male
# ...
